# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sebi061/VideoAdEngagement/blob/main/1_Cone_repo.ipynb)

# %%
### Set data directory
##################

# connect to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
### Set directory to google drive ###
#####################################

your_directory = ''
# %cd /content/drive/MyDrive/{your_directory}
# Out:
# /content/drive/MyDrive/0_Masterarbeit/4_2_check_git_repo

# %%
### Enter personal data ###
###########################

# %%
### Clone to google drive ###
#############################

# !git clone https://{git_token}@github.com/{username}/{repository}
# Out:
# Cloning into 'VideoAdEngagement'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 9 (delta 1), reused 8 (delta 0), pack-reused 0
# Unpacking objects: 100% (9/9), 15.21 KiB | 171.00 KiB/s, done.
